# %%
# import basic modules here 
import numpy as np
import cv2
import os 
import glob
import time
import sys
import json
import slidingwindow as sw
import matplotlib.pyplot as plt 
import pycocotools.mask as maskUtils
import mmcv 
import torch
from pycocotools.coco import COCO
from pycocotools import coco

# import mmdet-related modules 
from mmdet.apis import init_detector, inference_detector
from mmdet.datasets import build_dataloader, build_dataset
from mmdet.models import build_detector
from mmcv.runner import load_checkpoint
from mmcv.parallel import MMDataParallel
from scipy.ndimage import binary_fill_holes

# import shm_tools here
sys.path.append('..')
from shm_tools.shm_utils import imread, imwrite

# %%
# !python tools/coco_error_analysis.py mask_rcnn_test-dev_results.segm.json ./imsave \
--ann /home/soojin/mmdetection/data/concrete_damage_autocon/annotations/instances_test2018.json
# Out:
# -------------create ./imsave-----------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.10s)
# creating index...
# index created!
# -------------create ./imsave/bbox/-----------------
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.55s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# --------------analyzing 1-crack---------------
# --------------analyzing 2-effl---------------
# --------------analyzing 3-rebar---------------
# --------------analyzing 4-spll---------------
# creating index...
# index created!
# creating index...
# index created!
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# Running per image evaluation...
# Evaluate annotation type *bbox*
# Running per image evaluation...
# Evaluate annotation type *bbox*
# ...

# %%
# !python tools/get_flops.py ./project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_r50_fpn_1x.py
# Out:
# 2020-03-27 09:47:04,883 - mmdet - INFO - load model from: torchvision://resnet50
# 2020-03-27 09:47:05,206 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# MaskRCNN(
#   687.011 GMac, 100.000% MACs,
#   (backbone): ResNet(
#     84.077 GMac, 12.238% MACs,
#     (conv1): Conv2d(2.408 GMac, 0.351% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(0.033 GMac, 0.005% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(0.016 GMac, 0.002% MACs, inplace=True)
#     (maxpool): MaxPool2d(0.016 GMac, 0.002% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       13.885 GMac, 2.021% MACs,
#       (0): Bottleneck(
#         4.825 GMac, 0.702% MACs,
#         (conv1): Conv2d(0.262 GMac, 0.038% MACs, 64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
# !./tools/dist_test.sh /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/bilin_112/mask_rcnn_r101_fpn_1x_mask_bilin_112_overlap.py \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_r101_fpn_1x_mask_bilin_112_overlap/epoch_50.pth \
    3 --out result.pkl --format_only --options "jsonfile_prefix=./mask_rcnn_test-dev_results"
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 12.3 task/s, elapsed: 23s, ETA:     0s
# writing results to result.pkl

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_49.pth \
    3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.5 task/s, elapsed: 24s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.17s).
# Accumulating evaluation results...
# DONE (t=0.12s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.227
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_48.pth \
    3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# Done (t=0.03s)
# creating index...
# index created!
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.3 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.18s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.226
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_47.pth \
    3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.3 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.20s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_46.pth \
    3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.5 task/s, elapsed: 24s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.13s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_45.pth \
    3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.1 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.16s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.222
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_44.pth \
    3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# Done (t=0.04s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.7 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.16s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_43.pth \
    3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.3 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.17s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.227
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_42.pth \
    3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.1 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.16s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.225
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_41.pth \
    3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.2 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.20s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_40.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.1 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.15s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_39.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.0 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.28s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_38.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.9 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.15s).
# Accumulating evaluation results...
# DONE (t=0.13s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.224
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_37.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 9.6 task/s, elapsed: 29s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.65s).
# Accumulating evaluation results...
# DONE (t=0.17s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.172
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_36.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 9.3 task/s, elapsed: 30s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.61s).
# Accumulating evaluation results...
# DONE (t=0.17s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.169
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_35.pth \
3 --eval bbox segm

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_34.pth \
3 --eval bbox segm

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_33.pth \
3 --eval bbox segm

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_32.pth \
3 --eval bbox segm

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_31.pth \
3 --eval bbox segm

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_30.pth \
3 --eval bbox segm

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_29.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# loading annotations into memory...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.0 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.07s).
# Accumulating evaluation results...
# DONE (t=0.17s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.138
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_28.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.1 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.06s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.134
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_27.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.9 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.05s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.135
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_26.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.9 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.01s).
# Accumulating evaluation results...
# DONE (t=0.18s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.134
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_25.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# Done (t=0.02s)
# creating index...
# index created!
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.2 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.98s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.132
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_24.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.3 task/s, elapsed: 25s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.03s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.132
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_23.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.5 task/s, elapsed: 24s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.04s).
# Accumulating evaluation results...
# DONE (t=0.17s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_22.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.4 task/s, elapsed: 24s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.12s).
# Accumulating evaluation results...
# DONE (t=0.18s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.130
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_21.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.9 task/s, elapsed: 23s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.99s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_20.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.5 task/s, elapsed: 27s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.47s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_19.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.7 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.36s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.188
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_18.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.6 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.40s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.192
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_17.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.7 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.42s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.191
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_16.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.6 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.43s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_15.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.6 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.52s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_14.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.4 task/s, elapsed: 27s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.05s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.42s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.188
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_13.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.8 task/s, elapsed: 26s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.38s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.187
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_12.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.4 task/s, elapsed: 27s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.42s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.186
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_11.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# Done (t=0.02s)
# creating index...
# index created!
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.3 task/s, elapsed: 27s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.46s).
# Accumulating evaluation results...
# DONE (t=0.16s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.186
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_10.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 10.0 task/s, elapsed: 28s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.11s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.54s).
# Accumulating evaluation results...
# DONE (t=0.17s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.177
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_9.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 9.7 task/s, elapsed: 29s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.11s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.57s).
# Accumulating evaluation results...
# DONE (t=0.19s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.173
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_8.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 8.1 task/s, elapsed: 35s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.15s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.93s).
# Accumulating evaluation results...
# DONE (t=0.22s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.133
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_7.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 11.5 task/s, elapsed: 24s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.25s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.112
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_6.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 7.5 task/s, elapsed: 37s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.15s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.68s).
# Accumulating evaluation results...
# DONE (t=0.32s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.079
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_5.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# Done (t=0.03s)
# creating index...
# index created!
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 7.1 task/s, elapsed: 39s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.17s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=3.08s).
# Accumulating evaluation results...
# DONE (t=0.24s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.077
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_4.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 7.3 task/s, elapsed: 38s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.17s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=3.20s).
# Accumulating evaluation results...
# DONE (t=0.24s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.054
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_3.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 9.9 task/s, elapsed: 28s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.58s).
# Accumulating evaluation results...
# DONE (t=0.15s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.039
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_2.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 6.4 task/s, elapsed: 43s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.20s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=3.47s).
# Accumulating evaluation results...
# DONE (t=0.29s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.020
# ...

# %%
# !./tools/dist_test.sh  /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py  \
    /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_1.pth \
3 --eval bbox segm
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Done (t=0.03s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 279/277, 19.0 task/s, elapsed: 15s, ETA:     0s
# Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.27s).
# Accumulating evaluation results...
# DONE (t=0.07s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
# ...

# %%
config = ' /home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py '
checkpoint = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_50.pth'

cfg = mmcv.Config.fromfile(config)

# set cudnn_benchmark
if cfg.get('cudnn_benchmark', False):
    torch.backends.cudnn.benchmark = True
    
cfg.model.pretrained = None
cfg.data.val.test_mode = True

show = False

# build the dataloader
# TODO: support multiple images per gpu (only minor changes are needed)
dataset = build_dataset(cfg.data.val)
data_loader = build_dataloader(
    dataset,
    imgs_per_gpu=1,
    workers_per_gpu=cfg.data.workers_per_gpu,
    dist=False,
    shuffle=False)

# build the model and load checkpoint
model = build_detector(cfg.model, train_cfg=None, test_cfg=cfg.test_cfg)
checkpoint = load_checkpoint(model, checkpoint, map_location='cpu')

# old versions did not save class info in checkpoints, this walkaround is
# for backward compatibility
if 'CLASSES' in checkpoint['meta']:
    model.CLASSES = checkpoint['meta']['CLASSES']
else:
    model.CLASSES = dataset.CLASSES
    
model = MMDataParallel(model, device_ids=[0])    
model.eval()
results = []
dataset = data_loader.dataset
prog_bar = mmcv.ProgressBar(len(dataset))

for i, data in enumerate(data_loader):
    with torch.no_grad():
        result = model(return_loss=False, rescale=not show, **data)
    results.append(result)

    if show:
        model.module.show_result(data, result)

    batch_size = data['img'][0].size(0)
    for _ in range(batch_size):
        prog_bar.update()
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
