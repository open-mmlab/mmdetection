# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from torchsummaryX import summary
from mmdet.apis import init_detector, inference_detector, show_result
import torch

config_file = 'configs/ssd512_coco.py'
checkpoint_file = 'checkpoints/ssd512_coco_vgg16_caffe_120e_20181221-d48b0be8.pth'

# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')
print(model)
# Out:
# /home/szjt/yzh/mmdetection/mmdet/apis/inference.py:39: UserWarning: Class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn('Class names are not saved in the checkpoint\'s '
# SingleStageDetector(
#   (backbone): SSDVGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
from torchsummaryX import summary
from mmdet.apis import init_detector, inference_detector, show_result
import torch
config_file = 'configs/test/test1.py'
checkpoint_file = None

# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')
print(model)
# Out:
# SingleStageDetector(
#   (backbone): RefineDetVGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %%
f=(1,2,3)
print(f)
# Out:
# (1, 2, 3)

# %%
from __future__ import division

import argparse
import os
from mmcv import Config

from mmdet import __version__
from mmdet.datasets import get_dataset
from mmdet.apis import (train_detector, init_dist, get_root_logger,
                        set_random_seed)
from mmdet.models import build_detector
import torch

config_file = 'configs/test/test1.py'
# config_file = 'configs/ssd512_coco.py'
checkpoint_file = None
cfg = Config.fromfile(config_file)
# init logger before other steps
logger = get_root_logger(cfg.log_level)
logger.info('Distributed training: {}'.format(False))

cfg.gpus = 1
model = build_detector(
        cfg.model, train_cfg=cfg.train_cfg, test_cfg=cfg.test_cfg)
print(model)
train_dataset = get_dataset(cfg.data.train)
model.CLASSES = train_dataset.CLASSES
train_detector(
        model,
        train_dataset,
        cfg,
        distributed=False,
        validate=False,
        logger=logger)
# Out:
# 2019-06-23 20:17:04,988 - INFO - Distributed training: False
# 2019-06-23 20:17:05,191 - INFO - load model from: data/pretrained/vgg16_caffe-292e1171.pth
# 2019-06-23 20:17:05,223 - WARNING - missing keys in source state_dict: extra.3.weight, l2_norm.weight, extra.1.bias, extra.3.bias, extra.0.bias, extra.0.weight, extra.2.weight, extra.1.weight, extra.2.bias
# SingleStageDetector(
#   (backbone): RefineDetVGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace)
# ...

# %%
# summary(model, torch.zeros((1, 3, 512, 512)), 5)

# %%
# test a single image and show the results
img = 'test.jpg'  # or img = mmcv.imread(img), which will only load it once
result = inference_detector(model, img)
show_result(img, result, model.CLASSES)

# test a list of images and write the results to image files
# imgs = ['test1.jpg', 'test2.jpg']
# for i, result in enumerate(inference_detector(model, imgs):
#     show_result(imgs[i], result, model.CLASSES, out_file='result_{}.jpg'.format(i))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5d0e62d06ccd> in <module>
#       2 img = 'test.jpg'  # or img = mmcv.imread(img), which will only load it once
#       3 result = inference_detector(model, img)
# ----> 4 show_result(img, result, model.CLASSES)
#       5
#       6 # test a list of images and write the results to image files
#
# ~/anaconda3/envs/open-mmlab/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     537                 return modules[name]
#     538         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 539             type(self).__name__, name))
#     540
#     541     def __setattr__(self, name, value):
#
# AttributeError: 'SingleStageDetector' object has no attribute 'CLASSES'
