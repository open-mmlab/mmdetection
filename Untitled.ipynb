# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/mask_rcnn_r101_fpn_1x_overlap.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-25 21:05:22,784 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/mask_rcnn_r101_fpn_1x_normal.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-25 21:42:12,423 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/mask_rcnn_r101_fpn_1x_non_overlap.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-25 22:14:19,976 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/deconv_112/mask_rcnn_r101_fpn_1x_mask_112_non_overlap.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-22 23:25:55,294 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/deconv_112/mask_rcnn_r101_fpn_1x_mask_112_normal.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 01:15:21,195 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/deconv_56/mask_rcnn_r101_fpn_1x_mask_deconv_56_non_overlap.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 02:49:19,248 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/deconv_56/mask_rcnn_r101_fpn_1x_mask_deconv_56_normal.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 04:20:23,053 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/deconv_56/mask_rcnn_r101_fpn_1x_mask_deconv_56_overlap.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 05:43:46,153 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/bilin_112/mask_rcnn_r101_fpn_1x_mask_bilin_112_non_overlap.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 06:23:43,613 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/bilin_112/mask_rcnn_r101_fpn_1x_mask_bilin_112_normal.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 08:03:16,156 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/bilin_112/mask_rcnn_r101_fpn_1x_mask_bilin_112_overlap.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 09:31:07,917 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/bilin_56/mask_rcnn_r101_fpn_1x_mask_bilin_56_non_overlap.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 11:19:36,868 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/bilin_56/mask_rcnn_r101_fpn_1x_mask_bilin_56_normal.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 12:49:59,551 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/bilin_56/mask_rcnn_r101_fpn_1x_mask_bilin_56_overlap.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 14:12:48,997 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_hrnetv2p_w32_1x.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 15:49:21,452 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_mobilenetv3_fpn_backbone_pretrained.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 16:08:29,451 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_r50_fpn_1x.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 17:02:18,977 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# !./tools/dist_train.sh project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py 3
# Out:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# 2020-03-23 18:45:26,432 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.7.1 (default, Dec 14 2018, 19:28:38) [GCC 7.3.0]
# CUDA available: True
# CUDA_HOME: /usr/local/cuda-10.1
# NVCC: Cuda compilation tools, release 10.1, V10.1.243
# GPU 0,1,2: TITAN RTX
# GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# PyTorch: 1.3.1
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - Intel(R) Math Kernel Library Version 2019.0.4 Product Build 20190411 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v0.20.5 (Git Hash 0125f28c61c1f822fd48570b4c1066f96fcb9b2e)
# ...

# %%
# import basic modules here 
import numpy as np
import cv2
import os 
import glob
import time
import sys
import json
import slidingwindow as sw
import matplotlib.pyplot as plt 
import pycocotools.mask as maskUtils
import mmcv 
import torch
from pycocotools.coco import COCO
from pycocotools import coco
from IPython.display import clear_output, display

# import mmdet-related modules 
from mmdet.apis import init_detector, inference_detector
from mmdet.datasets import build_dataloader, build_dataset
from mmdet.models import build_detector
from mmcv.runner import load_checkpoint
from mmcv.parallel import MMDataParallel
from scipy.ndimage import binary_fill_holes

# import shm_tools here
sys.path.append('..')
from shm_tools.shm_utils import imread, imwrite

# %%
import logging

class AverageMeter(object):
    # This function is imported from https://github.com/hszhao/semseg/blob/master/util/util.py
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        
def comparison_operator(img, thr, ind='>'):
    import operator
    if ind == '==':
        return operator.eq(img, thr)
    elif ind == '<':
        return operator.lt(img, thr)
    elif ind == '>':
        return operator.gt(img, thr)
    elif ind == '!=':
        return operator.ne(img, thr)


def intersectionAndUnion(output, target, K, ignore_index=255):
    # This function is imported from https://github.com/hszhao/semseg/blob/master/util/util.py
    # 'K' classes, output and target sizes are N or N * L or N * H * W, each value in range 0 to K - 1.
    assert (output.ndim in [1, 2, 3])
    assert output.shape == target.shape
    output = output.reshape(output.size).copy()
    target = target.reshape(target.size)
    output[np.where(target == ignore_index)[0]] = ignore_index
    intersection = output[np.where(output == target)[0]]
    area_intersection, _ = np.histogram(intersection, bins=np.arange(K+1))
    area_output, _ = np.histogram(output, bins=np.arange(K+1))
    area_target, _ = np.histogram(target, bins=np.arange(K+1))
    area_union = area_output + area_target - area_intersection
    return area_intersection, area_union, area_target


def cal_acc(data_list, pred_folder, classes, names):
    # This function is imported from https://github.com/hszhao/semseg/blob/master/util/util.py
    intersection_meter = AverageMeter()
    union_meter = AverageMeter()
    target_meter = AverageMeter()

    for i, (image_path, target_path) in enumerate(data_list):
        image_name = image_path.split('/')[-1].split('.')[0]
        pred = cv2.imread(os.path.join(pred_folder, image_name+'.png'), cv2.IMREAD_GRAYSCALE)
        target = cv2.imread(target_path, cv2.IMREAD_GRAYSCALE)
        intersection, union, target = intersectionAndUnion(pred, target, classes)
        intersection_meter.update(intersection)
        union_meter.update(union)
        target_meter.update(target)
        accuracy = sum(intersection_meter.val) / (sum(target_meter.val) + 1e-10)
        logger.info('Evaluating {0}/{1} on image {2}, accuracy {3:.4f}.'.format(i + 1, len(data_list), image_name+'.png', accuracy))

    iou_class = intersection_meter.sum / (union_meter.sum + 1e-10)
    accuracy_class = intersection_meter.sum / (target_meter.sum + 1e-10)
    mIoU = np.mean(iou_class)
    mAcc = np.mean(accuracy_class)
    allAcc = sum(intersection_meter.sum) / (sum(target_meter.sum) + 1e-10)

    logger.info('Eval result: mIoU/mAcc/allAcc {:.4f}/{:.4f}/{:.4f}.'.format(mIoU, mAcc, allAcc))
    for i in range(classes):
        logger.info('Class_{} result: iou/accuracy {:.4f}/{:.4f}, name: {}.'.format(i, iou_class[i], accuracy_class[i], names[i]))

# %%
config = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/backbones/mask_rcnn_x101_64x4d_fpn_1x.py'
checkpoint = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_x101_64x4d_fpn_1x/epoch_42.pth'

cfg = mmcv.Config.fromfile(config)

# set cudnn_benchmark
if cfg.get('cudnn_benchmark', False):
    torch.backends.cudnn.benchmark = True
    
cfg.model.pretrained = None
cfg.data.test.test_mode = True

show = True 

# build the dataloader
# TODO: support multiple images per gpu (only minor changes are needed)
dataset = build_dataset(cfg.data.test)
data_loader = build_dataloader(
    dataset,
    imgs_per_gpu=1,
    workers_per_gpu=cfg.data.workers_per_gpu,
    dist=False,
    shuffle=False)

# build the model and load checkpoint
model = build_detector(cfg.model, train_cfg=None, test_cfg=cfg.test_cfg)
checkpoint = load_checkpoint(model, checkpoint, map_location='cpu')

# old versions did not save class info in checkpoints, this walkaround is
# for backward compatibility
if 'CLASSES' in checkpoint['meta']:
    model.CLASSES = checkpoint['meta']['CLASSES']
else:
    model.CLASSES = dataset.CLASSES
    
model = MMDataParallel(model, device_ids=[0])    
model.eval()
results = []
dataset = data_loader.dataset
prog_bar = mmcv.ProgressBar(len(dataset))

try : 
    for i, data in enumerate(data_loader):
    
        with torch.no_grad():
            result = model(return_loss=False, rescale=not show, **data)
        results.append(result)

        if show:
            model.module.show_result(data, result)

        batch_size = data['img'][0].size(0)
        for _ in range(batch_size):
            prog_bar.update()
except FileNotFoundError as  e: 
    print('Error') 
    
        
seg_results = []
num_class = len(dataset.CLASSES) + 1 # background + object classes 

for img_num, result in enumerate(results) : 
    
    bbox_result, segm_result = result
    
    for segm_result_ in segm_result : 
        if segm_result_:
            img_size = segm_result_[0]['size']
    seg_sum = np.zeros((img_size[0], img_size[1], num_class), dtype=np.float32)
    mask_sum = np.zeros((img_size[0], img_size[1]) , dtype=np.bool)

    for class_, bboxes in enumerate(bbox_result):
        
        class_idx = class_ + 1 

        for idx, bbox in enumerate(bboxes) : 
            confidence = bbox[-1]
            if confidence >= 0.5 : 
                mask = maskUtils.decode(segm_result[class_][idx]) 
                mask_sum = mask_sum  + mask
                seg_sum[:, :, class_idx] += confidence*mask

    seg_sum[:,:, 0] = mask_sum == 0

    seg_sum = torch.from_numpy(np.transpose(seg_sum, (2, 0, 1)))
    seg_sum = seg_sum.unsqueeze(0) # nn.softmax requires 4D tensor not 3D array 
    softmax = torch.nn.Softmax2d()
    output = softmax(seg_sum)
    _, indices = torch.max(output[0], 0)
    indices = indices.numpy()
    
    seg_results.append(indices)
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [                                ] 5/277, 0.5 task/s, elapsed: 10s, ETA:   543sError

# %%
# create segmentation ground truth from instance segementation annotation json 
annotation = COCO(cfg.data.val['ann_file'])

cat_ids = annotation.getCatIds()

cat2label = {
    cat_id: i + 1
    for i, cat_id in enumerate(cat_ids)
}

img_ids = annotation.getImgIds()
img_infos = []

for i in img_ids:
    info = annotation.loadImgs([i])[0]
    info['filename'] = info['file_name']
    img_infos.append(info)
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!

# %%
seg_gts = [] 

for img_info in img_infos :
    seg_gt_3d = np.zeros((img_info['height'], img_info['width'], num_class), dtype=np.uint8)
    img_id = img_info['id']
    ann_ids = annotation.getAnnIds(imgIds=[img_id])
    ann_info = annotation.loadAnns(ann_ids)

    for ann in ann_info:
        coco_mask = annotation.annToMask(ann)
        seg_gt_3d[:, :, ann['category_id'] + 1 ] = coco_mask # class idx starts from background as zero. 
        
    seg_gt_2d = np.zeros((img_info['height'], img_info['width']), dtype=np.uint8)
    
    seg_gt_2d[seg_gt_3d[:, :, 2] == 1] = 2 # efflorescence 
    seg_gt_2d[seg_gt_3d[:, :, 4] == 1] = 4 # spalling 
    seg_gt_2d[seg_gt_3d[:, :, 3] == 1] = 3 # rebar exposure 
    seg_gt_2d[seg_gt_3d[:, :, 1] == 1] = 1 # crack 
    
    seg_gts.append(seg_gt_2d)

# %%
intersection_meter = AverageMeter()
union_meter = AverageMeter()
target_meter = AverageMeter()


for img_num, seg_gt in enumerate(seg_gts):
    config = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/deconv_112/mask_rcnn_r101_fpn_1x_mask_112_normal.py '
    checkpoint = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_r101_fpn_1x_mask_112_overlap/epoch_50.pth'
    intersection, union, target = intersectionAndUnion(seg_results[img_num], seg_gt, num_class)
    intersection_meter.update(intersection)
    union_meter.update(union)
    target_meter.update(target)
    accuracy = sum(intersection_meter.val) / (sum(target_meter.val) + 1e-10)

iou_class = intersection_meter.sum / (union_meter.sum + 1e-10)
accuracy_class = intersection_meter.sum / (target_meter.sum + 1e-10)
mIoU = np.mean(iou_class)
mAcc = np.mean(accuracy_class)
allAcc = sum(intersection_meter.sum) / (sum(target_meter.sum) + 1e-10)

print('mIoU:', mIoU, 'mAcc:', mAcc, 'allAcc:', allAcc)
# Out:
# mIoU: 0.4030424862352017 mAcc: 0.6317263443657773 allAcc: 0.9536662204130818

# %%
path = '/home/soojin/mmdetection/data/concrete_damage_autocon/test2018/'
im_list = glob.glob(os.path.join(path,'*.jpg')) + glob.glob(os.path.join(path,'*.JPG'))

config = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/deconv_112/mask_rcnn_r101_fpn_1x_mask_112_non_overlap.py'
checkpoint = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_r101_fpn_1x_mask_112_non_overlap/epoch_50.pth'
device = 'cuda:0'
model = init_detector(config, checkpoint, device=device)
bbox_list = []
w_list = [] 
h_list = []
for img_num , img_path in enumerate(im_list): 
    clear_output(wait=True)
    print('Image No.'+ str(img_num+1) + 'is under process')
    img_name = os.path.basename(img_path)   
    image = imread(img_path)
    result = inference_detector(model, img_path)
 
    bbox_result, segm_result = result

    for class_, bboxes in enumerate(bbox_result):
        class_idx = class_ + 1 

        for idx, bbox in enumerate(bboxes) : 
            confidence = bbox[-1]
            if confidence >= 0.5 : 
                bbox_list.append(bbox)
                x1, y1, x2, y2, _ = bbox
                w_list.append(x2 - x1) 
                h_list.append(y2 - y1)
# Out:
# Image No.279is under process

# %%
plt.figure(figsize=(10, 10))

n, bins, patches = plt.hist(np.asarray(w_list, dtype = np.int64), 50, density=False, facecolor='m', alpha=0.75)


plt.xlabel('Bounding Box Width(pixels)', **hfont)
plt.ylabel('Number of Bounding Boxes', **hfont)

plt.xlim([0, 1024])
plt.ylim([0, 700])
# plt.title('Histogram of bounding box width distribution')
plt.grid(True)
plt.rcParams.update({'font.size':25})
plt.show()

# %%
path = '/home/soojin/mmdetection/data/concrete_damage_autocon/test2018/'
im_list = glob.glob(os.path.join(path,'*.jpg')) + glob.glob(os.path.join(path,'*.JPG'))

config = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/bilin_112/mask_rcnn_r101_fpn_1x_mask_bilin_112_overlap.py'
checkpoint = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_r101_fpn_1x_mask_bilin_112_overlap/epoch_42.pth'
device = 'cuda:0'
model = init_detector(config, checkpoint, device=device)

intersection_meter = AverageMeter()
union_meter = AverageMeter()
target_meter = AverageMeter()

intersection_list = []
union_list = []
target_list = []

for img_num , img_path in enumerate(im_list): 
    clear_output(wait=True)
    print('Image No.'+ str(img_num+1) + 'is under process')
    img_name = os.path.basename(img_path)   
    image = imread(img_path)
    result = inference_detector(model, img_path)
    

    num_class = 5 # background + object classes 
    bbox_result, segm_result = result

    for segm_result_ in segm_result : 
        if segm_result_:
            img_size = segm_result_[0]['size']
    seg_sum = np.zeros((img_size[0], img_size[1], num_class), dtype=np.float32)
    mask_sum = np.zeros((img_size[0], img_size[1]) , dtype=np.bool)

    for class_, bboxes in enumerate(bbox_result):

        class_idx = class_ + 1 

        for idx, bbox in enumerate(bboxes) : 
            confidence = bbox[-1]
            if confidence >= 0.5 : 
                mask = maskUtils.decode(segm_result[class_][idx]) 
                mask_sum = mask_sum  + mask
                seg_sum[:, :, class_idx] += mask

    seg_sum[:,:, 0] = mask_sum == 0
    seg_sum[seg_sum > 1] = 1
    seg_2d = np.zeros((image.shape[0], image.shape[1]), dtype = np.uint8)
    seg_2d[seg_sum[:, :, 2] == 1] = 2 # efflorescence _non_overlap
    seg_2d[seg_sum[:, :, 4] == 1] = 4 # spalling 
    seg_2d[seg_sum[:, :, 3] == 1] = 3 # rebar exposure 
    seg_2d[seg_sum[:, :, 1] == 1] = 1 # crack 
    
    


#     results = model.detect([image], verbose=1)

    fast_inference = False
    annot_path = os.path.join(path, 'annot')
    annot_img_list = glob.glob(os.path.join(annot_path, os.path.splitext(img_name)[0]+ '*.jpg'))


#     damage_detection_areas = np.zeros((image.shape[0], image.shape[1], 4), dtype = np.uint8)

#     for obj_num, class_id in enumerate(results[0]['class_ids']) : 
#         mask = results[0]['masks'][:,:,obj_num]
#         damage_detection_areas[:, :, class_id-1] = damage_detection_areas[:, :, class_id-1] + mask

#     damage_detection_areas[damage_detection_areas > 1 ] = 1    
#     seg_2d = np.zeros((image.shape[0], image.shape[1]), dtype = np.uint8)

#     seg_2d[damage_detection_areas[:, :, 3] == 1] = 4 # spalling 
#     seg_2d[damage_detection_areas[:, :, 1] == 1] = 2 # efflorescence 
#     seg_2d[damage_detection_areas[:, :, 2] == 1] = 3 # rebar exposure 
#     seg_2d[damage_detection_areas[:, :, 0] == 1] = 1 # crack 

    lower_thr = 150
    upper_thr = 200

    COLOR_OPTIONS = {
        'red'    :  [ '>', upper_thr,  '<', lower_thr, '<', lower_thr],
        'green'  : [ '<', lower_thr,  '>', upper_thr, '<', lower_thr],
    #     'blue'   :  [ '<', lower_thr,  '<', lower_thr, '>', upper_thr],
        'cyan'   : [ '<', 150,  '>', 200, '>', 200],
        'yellow' :  [ '>', 200,  '>', 200, '<', 150]
    }


    damage_areas = np.zeros((image.shape[0], image.shape[1], 4), dtype = np.uint8)

    for annot_img_path in annot_img_list:

        annot_img = imread(annot_img_path)

        for color_num, color in enumerate(COLOR_OPTIONS) : 

            rgb_thr = COLOR_OPTIONS[color]
            R = comparison_operator(annot_img[:, :, 0], rgb_thr[1], rgb_thr[0])
            G = comparison_operator(annot_img[:, :, 1], rgb_thr[3], rgb_thr[2])
            B = comparison_operator(annot_img[:, :, 2], rgb_thr[5], rgb_thr[4])

            damage_area = (R & G & B)
            damage_area = np.asarray(damage_area, dtype = np.uint8)
            damage_area = binary_fill_holes(damage_area).astype('uint8')
            damage_areas[:, :, color_num] = damage_areas[:, :, color_num] + damage_area

    damage_areas[damage_areas > 1 ] = 1

    seg_gt_2d = np.zeros((annot_img.shape[0], annot_img.shape[1]), dtype = np.uint8)

    seg_gt_2d[damage_areas[:, :, 3] == 1] = 4 # spalling 
    seg_gt_2d[damage_areas[:, :, 1] == 1] = 2 # efflorescence 
    seg_gt_2d[damage_areas[:, :, 2] == 1] = 3 # rebar exposure 
    seg_gt_2d[damage_areas[:, :, 0] == 1] = 1 # crack 


    intersection, union, target = intersectionAndUnion(seg_2d, seg_gt_2d, 5)
    intersection_list.append(intersection)
    union_list.append(union)
    target_list.append(target)
    intersection_meter.update(intersection[1:])
    union_meter.update(union[1:])
    target_meter.update(target[1:])
    accuracy = sum(intersection_meter.val) / (sum(target_meter.val) + 1e-10)

iou_class = intersection_meter.sum / (union_meter.sum + 1e-10)
accuracy_class = intersection_meter.sum / (target_meter.sum + 1e-10)
mIoU = np.mean(iou_class)
mAcc = np.mean(accuracy_class)
allAcc = sum(intersection_meter.sum) / (sum(target_meter.sum) + 1e-10)

print('mIoU:', mIoU, 'mAcc:', mAcc, 'allAcc:', allAcc)
# Out:
# Image No.279is under process
# mIoU: 0.5448268803054019 mAcc: 0.7009852959891153 allAcc: 0.7100384318328588

# %%
iou_class
# Out:
# array([0.49961696, 0.58134115, 0.5874613 , 0.66328925])

# %%
import skimage.io as io
import scipy
from skimage.measure import regionprops, label
import math


path = '/home/soojin/mmdetection/data/concrete_damage_autocon/test2018/'
im_list_path = glob.glob(os.path.join(path,'*.jpg')) + glob.glob(os.path.join(path,'*.JPG'))

# 49 47 48 
config = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/configs/bilin_112/mask_rcnn_r101_fpn_1x_mask_bilin_112_overlap.py'
checkpoint = '/home/soojin/mmdetection/project_work_dirs/multiple_damage_detection/work_dirs/mask_rcnn_r101_fpn_1x_mask_bilin_112_overlap/epoch_42.pth'
device = 'cuda:0'
model = init_detector(config, checkpoint, device=device)

annot_dir = os.path.join(path ,'annot')

average_precision = 0
average_recall = 0
average_precision_pix = 0
average_recall_pix = 0
for org_img in range(np.size(im_list_path)):    
# for org_img in range(10, 11):    
    
    image = io.imread(im_list_path [org_img])
    clear_output(wait=True)
    print(org_img, im_list_path[org_img])
    if image.ndim == 2 : image = color.gray2rgb(image)

    result = inference_detector(model, image)
    
    r={}
    r['class_ids'] = []
    r['rois'] = []
    r['scores'] = []
    r['masks'] = []

    bbox_result, segm_result = result


    for class_num, bbox_with_class in enumerate(bbox_result) : 
        for box_num, bbox in enumerate(bbox_with_class) :
            if bbox[-1] > 0.5 :
                r['class_ids'].append(class_num+1)
                r['rois'].append(bbox[:-1])
                r['scores'].append(bbox[-1])
                if len(r['masks']) == 0 :

                    r['masks'] = maskUtils.decode(segm_result[class_num][box_num]) 
                    r['masks'] = r['masks'][:, :, np.newaxis]
                    r['masks'] = np.asarray(r['masks'])
                else : 
                    r['masks'] = np.dstack([r['masks'], maskUtils.decode(segm_result[class_num][box_num])])


    r['class_ids'] = np.asarray(r['class_ids'] )
    r['rois'] = np.asarray(r['rois'], dtype = np.int64)
    r['scores']= np.asarray(r['scores'])
    cls = r['class_ids']


   
    img_name = os.path.splitext(os.path.basename(im_list_path[org_img]))[0]
    annot_list_path = glob.glob(os.path.join(annot_dir, img_name+'*.jpg'))
    
    annot_class_by_number = np.zeros((image.shape[0], image.shape[1], 4))
    
    precision_count = 0
    
#     kernel = np.ones((5,5),np.uint8)
    for annot in range(np.size(annot_list_path)):
        
        annot_image = io.imread(annot_list_path[annot])

        # 1 : crack 2:efflorescence 3: rebar 4: spalling
        annot_class_by_number[np.logical_and.reduce([annot_image[:, :, 0] > 200,
                                                     annot_image[:, :, 1] < 150,
                                                     annot_image[:, :, 2] < 150]), 0] = 255
#         annot_class_by_number[:,:,0] = cv2.dilate(annot_class_by_number[:,:,0],kernel,iterations = 1)
        
        
        annot_class_by_number[np.logical_and.reduce([annot_image[:, :, 0] < 150,
                                                     annot_image[:, :, 1] > 200,
                                                     annot_image[:, :, 2] < 150]), 1] = 255
#         annot_class_by_number[:,:,1] = cv2.dilate(annot_class_by_number[:,:,1],kernel,iterations = 1)
        
        annot_class_by_number[np.logical_and.reduce([annot_image[:, :, 0] < 150,
                                                     annot_image[:, :, 1] > 200,
                                                     annot_image[:, :, 2] > 200]), 2] = 255
#         annot_class_by_number[:,:,2] = cv2.dilate(annot_class_by_number[:,:,2],kernel,iterations = 1)
        
        annot_class_by_number[np.logical_and.reduce([annot_image[:, :, 0] > 200,
                                                     annot_image[:, :, 1] > 200,
                                                     annot_image[:, :, 2] < 150]), 3] = 255
#         annot_class_by_number[:,:,3] = cv2.dilate(annot_class_by_number[:,:,3],kernel,iterations = 1)

        
        labels, num = label(annot_class_by_number[:,:,1],connectivity=2, return_num= True)
    
        for R in regionprops(labels):
            if R.area > 1:
                annot_class_by_number[:,:,1]=scipy.ndimage.binary_fill_holes(annot_class_by_number[:,:,1]).astype('uint8')*255
                
        labels, num = label(annot_class_by_number[:,:,2],connectivity=2, return_num= True)
    
        for R in regionprops(labels):
            if R.area > 1:
                annot_class_by_number[:,:,2]=scipy.ndimage.binary_fill_holes(annot_class_by_number[:,:,2]).astype('uint8')*255
                
        labels, num = label(annot_class_by_number[:,:,3],connectivity=2, return_num= True)
    
        for R in regionprops(labels):
            if R.area > 1:
                annot_class_by_number[:,:,3]=scipy.ndimage.binary_fill_holes(annot_class_by_number[:,:,3]).astype('uint8')*255
    
    confusion_mat_img = np.zeros((image.shape[0], image.shape[1], 4)) 
    
    mask_by_class = np.zeros((image.shape[0], image.shape[1], 4))
    
    
    pix_level_detection = np.zeros((image.shape[0], image.shape[1], 4))
    confusion_matrix = np.zeros((image.shape[0], image.shape[1], 4))
    
    per_class_recall = np.zeros(4)
    per_class_precision = np.zeros(4)
    NTP_NFP_list = np.zeros(4)
    NTP_NFN_list = np.zeros(4)
    
    for i_cls in range(np.size(cls)): 
        pix_level_detection[r['masks'][:,:,i_cls]==1, r['class_ids'][i_cls]-1] = 255
    
    for i_cls in range(4): 
        confusion_matrix[:,:, i_cls] = pix_level_detection[:,:,i_cls] + annot_class_by_number[:,:,i_cls]
#         confusion_matrix[np.logical_and.reduce([pix_level_detection[:,:,i_cls] == 255, 
#                                                annot_class_temp[:,:,i_cls] == 0]), i_cls] = 2
#         confusion_matrix[np.logical_and.reduce([pix_level_detection[:,:,i_cls] == 0, 
#                                                annot_class_temp[:,:,i_cls] == 255]), i_cls] = 1
        
        NTP = np.sum(confusion_matrix[:,:,i_cls] > 500  )
        NTP_NFP = np.sum(pix_level_detection[:,:,i_cls] == 255)
        NTP_NFN = np.sum(annot_class_by_number[:,:,i_cls] == 255 )
        
        NTP_NFP_list = NTP_NFP
        NTP_NFN_list = NTP_NFN
#         print(NTP)
        
        per_class_recall[i_cls] = NTP / (NTP_NFN)
        per_class_precision[i_cls] = NTP / (NTP_NFP)
        
        
        
#     print(per_class_recall)    
#     print(per_class_precision) 
    pix_recall = np.nanmean(per_class_recall)
    pix_precision = np.nanmean(per_class_precision)
    

    
    average_precision_pix = average_precision_pix + pix_precision if not math.isnan(pix_precision) else average_precision_pix
    average_recall_pix = average_recall_pix + pix_recall  if not math.isnan(pix_precision) else average_recall_pix
        
    for i_cls in range(np.size(cls)): 
        confusion_mat = r['masks'][:,:,i_cls]+annot_class_by_number[:,:,r['class_ids'][i_cls]-1]/255
        mask_by_class[r['masks'][:,:,i_cls]==1, r['class_ids'][i_cls]-1] = 1
        try:
            pseudo_IoU = np.count_nonzero(confusion_mat == 2)/np.count_nonzero(r['masks'][:,:,i_cls] == 1)

        except ZeroDivisionError as e :
            pseudo_IoU = 0
        
#         print(pseudo_IoU)
        confusion_mat_img[r['masks'][:,:,i_cls], r['class_ids'][i_cls]-1] = 1  
        confusion_mat_img[confusion_mat == 2, r['class_ids'][i_cls]-1] = 2  
        if pseudo_IoU > 0.5 : 
            precision_count = precision_count + 1
            
    try :  
        precision = precision_count/np.size(cls)
        
    except ZeroDivisionError as e :
        precision = 0
    
    average_precision = average_precision + precision if not math.isnan(precision) else average_precision
    
    recall_count = 0 
    
    for annot in range(np.size(annot_list_path)):
        
        annot_image = io.imread(annot_list_path[annot])
        annot_class_temp = np.zeros((image.shape[0], image.shape[1], 4))
        
        
        
        # 1 : crack 2:efflorescence 3: rebar 4: spalling
        annot_class_temp[np.logical_and.reduce([annot_image[:, :, 0] > 200,
                                                     annot_image[:, :, 1] < 150,
                                                     annot_image[:, :, 2] < 150]), 0] = 255
#         annot_class_temp[:,:,0] = cv2.dilate(annot_class_temp[:,:,0],kernel,iterations = 1)
        
        annot_class_temp[np.logical_and.reduce([annot_image[:, :, 0] < 150,
                                                     annot_image[:, :, 1] > 200,
                                                     annot_image[:, :, 2] < 150]), 1] = 255
#         annot_class_temp[:,:,1] = cv2.dilate(annot_class_temp[:,:,1],kernel,iterations = 1)
        
        annot_class_temp[np.logical_and.reduce([annot_image[:, :, 0] < 150,
                                                     annot_image[:, :, 1] > 200,
                                                     annot_image[:, :, 2] > 200]), 2] = 255
#         annot_class_temp[:,:,2] = cv2.dilate(annot_class_temp[:,:,2],kernel,iterations = 1)
        
        annot_class_temp[np.logical_and.reduce([annot_image[:, :, 0] > 200,
                                                     annot_image[:, :, 1] > 200,
                                                     annot_image[:, :, 2] < 150]), 3] = 255
#         annot_class_temp[:,:,3] = cv2.dilate(annot_class_temp[:,:,3],kernel,iterations = 1)

        
        labels, num = label(annot_class_temp[:,:,1],connectivity=2, return_num= True)
        
        for R in regionprops(labels):
            if R.area > 1:
                annot_class_temp[:,:,1]=scipy.ndimage.binary_fill_holes(annot_class_temp[:,:,1]).astype('uint8')*255
                
        labels, num = label(annot_class_temp[:,:,2],connectivity=2, return_num= True)
        
        for R in regionprops(labels):
            if R.area > 1:
                annot_class_temp[:,:,2]=scipy.ndimage.binary_fill_holes(annot_class_temp[:,:,2]).astype('uint8')*255
                
        labels, num = label(annot_class_temp[:,:,3],connectivity=2, return_num= True)
    
        for R in regionprops(labels):
            if R.area > 1:
                annot_class_temp[:,:,3]=scipy.ndimage.binary_fill_holes(annot_class_temp[:,:,3]).astype('uint8')*255
        
        for i_cls in range(4): 
            if np.sum(annot_class_temp[:,:,i_cls]) > 0 :
                confusion_mat_recall = mask_by_class[:,:,i_cls]+annot_class_temp[:,:,i_cls]/255  
                try:
                    pseudo_IoU_recall = np.count_nonzero(confusion_mat_recall == 2)/np.count_nonzero(annot_class_temp[:,:,i_cls] == 255)

                except ZeroDivisionError as e :
                    pseudo_IoU_recall = 0
                
                if pseudo_IoU_recall > 0.5 : 
                    recall_count = recall_count + 1

    try :  
        recall = recall_count/np.size(annot_list_path)
        
    except ZeroDivisionError as e :
        recall = 0
    
    average_recall = average_recall + recall if not math.isnan(recall) else  average_recall  
                
average_recall = average_recall/np.size(im_list_path)
average_precision = average_precision/np.size(im_list_path)
average_recall_pix = average_recall_pix/np.size(im_list_path)
average_precision_pix = average_precision_pix/np.size(im_list_path)

print(average_precision)
print(average_recall)
print(average_precision_pix)
print(average_recall_pix)
# Out:
# 278 /home/soojin/mmdetection/data/concrete_damage_autocon/test2018/200205_bk_0373.JPG
# 0.701334012522951
# 0.7896816649979204
# 0.595718710068958
# 0.7371978452463863

# %%
iou_class
# Out:
# array([0.49961696, 0.58134115, 0.5874613 , 0.66328925])

# %%
average_precision_pix
# Out:
# nan
